# %%
import pandas as pd

# %%
#only loading few columns while readign csv
df = pd.read_csv('airports.csv', usecols=['IATA_CODE', 'AIRPORT'])
df
# Out:
#     IATA_CODE                              AIRPORT
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
# [322 rows x 2 columns]

# %%
#test usecols with callable - 1st step 
def test(x):
    print(x)
    return x

df = pd.read_csv('airports.csv', usecols=test)
df
# Out:
# IATA_CODE
# AIRPORT
# CITY
# STATE
# COUNTRY
# LATITUDE
# LONGITUDE
# IATA_CODE
# AIRPORT
# CITY
# STATE
# COUNTRY
# LATITUDE
# LONGITUDE
# IATA_CODE
# AIRPORT
# CITY
# STATE
# COUNTRY
# LATITUDE
# LONGITUDE
#     IATA_CODE                              AIRPORT  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 0                         Allentown    PA     USA  40.65236  -75.44040
# 1                           Abilene    TX     USA  32.41132  -99.68190
# 2                       Albuquerque    NM     USA  35.04022 -106.60919
# 3                          Aberdeen    SD     USA  45.44906  -98.42183
# 4                            Albany    GA     USA  31.53552  -84.19447
# ..                              ...   ...     ...       ...        ...
# 317                        Wrangell    AK     USA  56.48433 -132.36982
# 318                West Yellowstone    MT     USA  44.68840 -111.11764
# 319  Fayetteville/Springdale/Rogers    AR     USA  36.28187  -94.30681
# 320                         Yakutat    AK     USA  59.50336 -139.66023
# 321                            Yuma    AZ     USA  32.65658 -114.60597
#
# [322 rows x 7 columns]

# %%
#select only few columns
def test(x):
    if x == 'AIRPORT' or x == 'IATA_CODE':
        return x

df = pd.read_csv('airports.csv', usecols=test)
df
# Out:
#     IATA_CODE                              AIRPORT
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
# [322 rows x 2 columns]

# %%
#dont load lattitude and longitude
def test(x):
    if x != 'LATITUDE' and x != 'LONGITUDE':
        return x
df = pd.read_csv('airports.csv', usecols=test)
df
# Out:
#     IATA_CODE                              AIRPORT  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY
# 0                         Allentown    PA     USA
# 1                           Abilene    TX     USA
# 2                       Albuquerque    NM     USA
# 3                          Aberdeen    SD     USA
# 4                            Albany    GA     USA
# ..                              ...   ...     ...
# 317                        Wrangell    AK     USA
# 318                West Yellowstone    MT     USA
# 319  Fayetteville/Springdale/Rogers    AR     USA
# 320                         Yakutat    AK     USA
# 321                            Yuma    AZ     USA
#
# [322 rows x 5 columns]

# %%
def test(x):
    #if x == 'LATITUDE' or x == 'LONGITUDE':
    if x not in ('LATITUDE' , 'LONGITUDE'):
        return x
    

df = pd.read_csv('airports.csv', usecols=test)
df
# Out:
#     IATA_CODE                              AIRPORT  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY
# 0                         Allentown    PA     USA
# 1                           Abilene    TX     USA
# 2                       Albuquerque    NM     USA
# 3                          Aberdeen    SD     USA
# 4                            Albany    GA     USA
# ..                              ...   ...     ...
# 317                        Wrangell    AK     USA
# 318                West Yellowstone    MT     USA
# 319  Fayetteville/Springdale/Rogers    AR     USA
# 320                         Yakutat    AK     USA
# 321                            Yuma    AZ     USA
#
# [322 rows x 5 columns]

# %%
df = pd.read_csv('airports.csv', usecols= lambda x: x not in ('LATITUDE' , 'LONGITUDE') )
df
# Out:
#     IATA_CODE                              AIRPORT  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY
# 0                         Allentown    PA     USA
# 1                           Abilene    TX     USA
# 2                       Albuquerque    NM     USA
# 3                          Aberdeen    SD     USA
# 4                            Albany    GA     USA
# ..                              ...   ...     ...
# 317                        Wrangell    AK     USA
# 318                West Yellowstone    MT     USA
# 319  Fayetteville/Springdale/Rogers    AR     USA
# 320                         Yakutat    AK     USA
# 321                            Yuma    AZ     USA
#
# [322 rows x 5 columns]

# %%
#Azure Machine Learning Studio

# %%
df = pd.read_csv('airlines_codes.csv', header=None, names=['codes','airlines'])
df
# Out:
#    codes                      airlines
# 0     UA         United Air Lines Inc.
# 1     AA        American Airlines Inc.
# 2     US               US Airways Inc.
# 3     F9        Frontier Airlines Inc.
# 4     B6               JetBlue Airways
# 5     OO         Skywest Airlines Inc.
# 6     AS          Alaska Airlines Inc.
# 7     NK              Spirit Air Lines
# 8     WN        Southwest Airlines Co.
# 9     DL          Delta Air Lines Inc.
# 10    EV   Atlantic Southeast Airlines
# 11    HA        Hawaiian Airlines Inc.
# 12    MQ  American Eagle Airlines Inc.
# 13    VX                Virgin America

# %%
df = pd.read_csv('airlines_codes.csv', nrows=10, header=None, names=['codes','airlines'])
df
# Out:
#   codes                airlines
# 0    UA   United Air Lines Inc.
# 1    AA  American Airlines Inc.
# 2    US         US Airways Inc.
# 3    F9  Frontier Airlines Inc.
# 4    B6         JetBlue Airways
# 5    OO   Skywest Airlines Inc.
# 6    AS    Alaska Airlines Inc.
# 7    NK        Spirit Air Lines
# 8    WN  Southwest Airlines Co.
# 9    DL    Delta Air Lines Inc.

# %%
#skip 3 rows  - all three works 
#df = pd.read_csv('airports.csv', nrows=10, skiprows=(1,2,3))
#df = pd.read_csv('airports.csv', nrows=10, skiprows=range(1,4))
df = pd.read_csv('airports.csv', nrows=10, skiprows=lambda x: 0 < x<4)
df
# Out:
#   IATA_CODE                                AIRPORT           CITY STATE  \
# 0       ABR              Aberdeen Regional Airport       Aberdeen    SD
# 1       ABY     Southwest Georgia Regional Airport         Albany    GA
# 2       ACK             Nantucket Memorial Airport      Nantucket    MA
# 3       ACT                  Waco Regional Airport           Waco    TX
# 4       ACV                         Arcata Airport  Arcata/Eureka    CA
# 5       ACY    Atlantic City International Airport  Atlantic City    NJ
# 6       ADK                           Adak Airport           Adak    AK
# 7       ADQ                         Kodiak Airport         Kodiak    AK
# 8       AEX       Alexandria International Airport     Alexandria    LA
# 9       AGS  Augusta Regional Airport (Bush Field)        Augusta    GA
#
#   COUNTRY  LATITUDE  LONGITUDE
# 0     USA  45.44906  -98.42183
# 1     USA  31.53552  -84.19447
# 2     USA  41.25305  -70.06018
# 3     USA  31.61129  -97.23052
# 4     USA  40.97812 -124.10862
# 5     USA  39.45758  -74.57717
# 6     USA  51.87796 -176.64603
# 7     USA  57.74997 -152.49386
# 8     USA  31.32737  -92.54856
# 9     USA  33.36996  -81.96450

# %%
#load last twenty rows 
df = pd.read_csv('airports.csv', nrows=10, skiprows=lambda x: 0 < x<4)

# %%
LineCount=len(open('airports.csv').readlines()) 
df=pd.read_csv('airports.csv', skiprows=range(1,LineCount-20))
df
# Out:
#    IATA_CODE                                            AIRPORT  \
# 0        TOL                             Toledo Express Airport
# 1        TPA                        Tampa International Airport
# 2        TRI                        Tri-Cities Regional Airport
# 3        TTN                             Trenton Mercer Airport
# 4        TUL                        Tulsa International Airport
# 5        TUS                       Tucson International Airport
# 6        TVC                             Cherry Capital Airport
# 7        TWF       Magic Valley Regional Airport (Joslin Field)
# 8        TXK            Texarkana Regional Airport (Webb Field)
# 9        TYR                      Tyler Pounds Regional Airport
# 10       TYS                               McGhee Tyson Airport
# 11       UST  Northeast Florida Regional Airport (St. August...
# 12       VEL                                     Valdez Airport
# 13       VLD                          Valdosta Regional Airport
# 14       VPS         Destin-Fort Walton Beach Airport/Eglin AFB
# 15       WRG                                   Wrangell Airport
# 16       WYS                             Westerly State Airport
# 17       XNA                Northwest Arkansas Regional Airport
# 18       YAK                                    Yakutat Airport
# 19       YUM                         Yuma International Airport
#
#                               CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 0                           Toledo    OH     USA  41.58681  -83.80783
# 1                            Tampa    FL     USA  27.97547  -82.53325
# 2                          Bristol    TN     USA  36.47521  -82.40742
# 3                          Trenton    NJ     USA  40.27669  -74.81347
# 4                            Tulsa    OK     USA  36.19837  -95.88824
# 5                           Tucson    AZ     USA  32.11608 -110.94103
# 6                    Traverse City    MI     USA  44.74144  -85.58224
# 7                       Twin Falls    ID     USA  42.48180 -114.48774
# 8                        Texarkana    AR     USA  33.45371  -93.99102
# 9                            Tyler    TX     USA  32.35414  -95.40239
# 10                       Knoxville    TN     USA  35.81249  -83.99286
# 11                   St. Augustine    FL     USA       NaN        NaN
# 12                          Vernal    UT     USA  40.44090 -109.50992
# 13                        Valdosta    GA     USA  30.78250  -83.27672
# 14                      Valparaiso    FL     USA  30.48325  -86.52540
# 15                        Wrangell    AK     USA  56.48433 -132.36982
# 16                West Yellowstone    MT     USA  44.68840 -111.11764
# 17  Fayetteville/Springdale/Rogers    AR     USA  36.28187  -94.30681
# 18                         Yakutat    AK     USA  59.50336 -139.66023
# 19                            Yuma    AZ     USA  32.65658 -114.60597

# %%
# Out:
# range(0, 303)
