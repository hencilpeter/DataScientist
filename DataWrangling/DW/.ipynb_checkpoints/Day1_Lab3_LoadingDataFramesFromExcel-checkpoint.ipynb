# %%
import pandas as pd

# %%
df=pd.read_excel('Financial Sample.xlsx', sheet_name='Sheet1')
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df=pd.read_excel('Financial Sample.xlsx', sheet_name=[0,1])

# %%
df[1]
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df=pd.read_excel('Financial Sample.xlsx', sheet_name=['Sheet1','Sheet2'])

# %%
df
# Out:
# {'Sheet1':               Segment                   Country    Product Discount Band  \
#  0          Government                    Canada  Carretera          None
#  1          Government                   Germany  Carretera          None
#  2           Midmarket                    France  Carretera          None
#  3           Midmarket                   Germany  Carretera          None
#  4           Midmarket                    Mexico  Carretera          None
#  ..                ...                       ...        ...           ...
#  695    Small Business                    France   Amarilla          High
#  696    Small Business                    Mexico   Amarilla          High
#  697        Government                    Mexico    Montana          High
#  698        Government                    Canada      Paseo          High
#  699  Channel Partners  United States of America        VTT          High
#
# ...

# %%
df=pd.concat(pd.read_excel('Financial Sample.xlsx', sheet_name=['Sheet1','Sheet2']))
df
# Out:
#                      Segment                   Country    Product  \
# Sheet1 0          Government                    Canada  Carretera
#        1          Government                   Germany  Carretera
#        2           Midmarket                    France  Carretera
#        3           Midmarket                   Germany  Carretera
#        4           Midmarket                    Mexico  Carretera
# ...                      ...                       ...        ...
# Sheet2 695    Small Business                    France   Amarilla
#        696    Small Business                    Mexico   Amarilla
#        697        Government                    Mexico    Montana
#        698        Government                    Canada      Paseo
#        699  Channel Partners  United States of America        VTT
#
#            Discount Band  Units Sold  Manufacturing Price  Sale Price  \
# Sheet1 0            None      1618.5                    3          20
# ...

# %%
#multi index data frame 
df.loc['Sheet2']
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df.loc[('Sheet2',0)]
# Out:
# Segment                         Government
# Country                             Canada
# Product                          Carretera
# Discount Band                         None
# Units Sold                          1618.5
# Manufacturing Price                      3
# Sale Price                              20
# Gross Sales                        32370.0
# Discounts                              0.0
#  Sales                             32370.0
# COGS                               16185.0
# Profit                             16185.0
# Date                   2014-01-01 00:00:00
# Month Number                             1
# Month Name                         January
# Year                                  2014
# Name: (Sheet2, 0), dtype: object

# %%
#save to anoher excel sheet
from pandas import ExcelWriter
with ExcelWriter('test1.xlsx') as writer:
    df.to_excel(writer)

# %%
df.to_excel('Test2.xlsx')
